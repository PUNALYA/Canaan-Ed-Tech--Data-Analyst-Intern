# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\punal\OneDrive\Desktop\Canaan Ed & Tech Internship\Week 1\netflix_reviews.csv")
df.head()
# Out:
#                                reviewId         userName  \
# 0  47547cc7-4cb3-4281-a54f-9aa02a4a9993       Hamza Muhd
# 1  e90ef8bf-c835-44d5-b296-ba8e61d8f3b1    Sourabh Dubey
# 2  5644d30f-0392-4d66-bbe1-821ab3445094  Ice man Ice man
# 3  d2e5e77f-65a0-42e0-9288-8a7eae905837     Ambika Masad
# 4  bcb140f6-0f29-4aaf-a072-74d6ced89971       Quinn H Jr
#
#                                   content  score  thumbsUpCount  \
# 0                                The best      1              0
# 1      we can see those movie who I loved      1              0
# 2  TV in master bed room is not coming in      1              0
# 3                                so bad 😡      1              0
# 4                                  Decent      3              0
#
#      reviewCreatedVersion                   at              appVersion
# 0  8.143.5 build 19 52400  2026-02-28 09:46:27  8.143.5 build 19 52400
# 1                     NaN  2026-02-28 09:23:40                     NaN
# 2    9.54.0 build 8 63892  2026-02-28 09:23:17    9.54.0 build 8 63892
# 3    9.55.0 build 6 63912  2026-02-28 08:30:33    9.55.0 build 6 63912
# 4    9.55.0 build 6 63912  2026-02-28 08:27:50    9.55.0 build 6 63912

# %%
df.shape
# Out:
# (147117, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147117 entries, 0 to 147116
# Data columns (total 8 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewId              147117 non-null  object
#  1   userName              147115 non-null  object
#  2   content               147111 non-null  object
#  3   score                 147117 non-null  int64
#  4   thumbsUpCount         147117 non-null  int64
#  5   reviewCreatedVersion  121020 non-null  object
#  6   at                    147117 non-null  object
#  7   appVersion            121020 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 9.0+ MB

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (146830, 8)

# %%
df.isnull().sum()
# Out:
# reviewId                    0
# userName                    2
# content                     6
# score                       0
# thumbsUpCount               0
# reviewCreatedVersion    26036
# at                          0
# appVersion              26036
# dtype: int64

# %%
df['userName'] = df['content'].fillna("Unknown")

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(" ", "_")

# %%
df.to_csv("cleaned_dataset.csv", index=False)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\punal'
