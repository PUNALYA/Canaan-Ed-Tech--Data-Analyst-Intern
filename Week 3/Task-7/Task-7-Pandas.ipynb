# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\punal\OneDrive\Desktop\Canaan Ed & Tech Internship\Week 3\Task-7\Task-7-sales_data.csv")
df.head()
# Out:
#   Product     Category  Price  Quantity
# 0  Laptop  Electronics  50000         5
# 1   Phone  Electronics  20000        10
# 2   Shirt     Clothing   1500        20
# 3   Shoes     Clothing   3000        15
# 4      TV  Electronics  40000         3

# %%
# Filter Electronics
electronics = df[df["Category"] == "Electronics"]
electronics
# Out:
#   Product     Category  Price  Quantity
# 0  Laptop  Electronics  50000         5
# 1   Phone  Electronics  20000        10
# 4      TV  Electronics  40000         3

# %%
# Filter Price greater than 10000
high_price = df[df["Price"] > 10000]
high_price
# Out:
#   Product     Category  Price  Quantity
# 0  Laptop  Electronics  50000         5
# 1   Phone  Electronics  20000        10
# 4      TV  Electronics  40000         3

# %%
# Gropyby
df.groupby("Category")["Price"].mean()
# Out:
# Category
# Clothing        2250.000000
# Electronics    36666.666667
# Name: Price, dtype: float64

# %%
df.groupby("Category")["Quantity"].sum()
# Out:
# Category
# Clothing       35
# Electronics    18
# Name: Quantity, dtype: int64

# %%
discount = pd.read_csv(r"C:\Users\punal\OneDrive\Desktop\Canaan Ed & Tech Internship\Week 3\Task-7\Task-7-discounts_data.csv")

merged_df = pd.merge(df, discount, on="Product")
merged_df
# Out:
#   Product     Category  Price  Quantity  Discount
# 0  Laptop  Electronics  50000         5        10
# 1   Phone  Electronics  20000        10         5
# 2   Shirt     Clothing   1500        20        15
# 3   Shoes     Clothing   3000        15        20
# 4      TV  Electronics  40000         3         8

# %%
#Sorting
df.sort_values(by="Price", ascending=False)
# Out:
#   Product     Category  Price  Quantity
# 0  Laptop  Electronics  50000         5
# 4      TV  Electronics  40000         3
# 1   Phone  Electronics  20000        10
# 3   Shoes     Clothing   3000        15
# 2   Shirt     Clothing   1500        20

# %%
df.sort_values(by="Quantity")
# Out:
#   Product     Category  Price  Quantity
# 4      TV  Electronics  40000         3
# 0  Laptop  Electronics  50000         5
# 1   Phone  Electronics  20000        10
# 3   Shoes     Clothing   3000        15
# 2   Shirt     Clothing   1500        20
