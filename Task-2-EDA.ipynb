# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\punal\OneDrive\Desktop\Canaan Ed & Tech Internship\Week 1\cleaned_dataset.csv")

# %%
df.describe()
# Out:
#                score  thumbsupcount
# count  146830.000000  146830.000000
# mean        2.871668       8.331124
# std         1.735115      90.261648
# min         1.000000       0.000000
# 25%         1.000000       0.000000
# 50%         3.000000       0.000000
# 75%         5.000000       1.000000
# max         5.000000    8032.000000

# %%
df.shape
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146830 entries, 0 to 146829
# Data columns (total 8 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewid              146830 non-null  object
#  1   username              146828 non-null  object
#  2   content               146824 non-null  object
#  3   score                 146830 non-null  int64
#  4   thumbsupcount         146830 non-null  int64
#  5   reviewcreatedversion  120794 non-null  object
#  6   at                    146830 non-null  object
#  7   appversion            120794 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 9.0+ MB
# reviewid                    0
# username                    2
# content                     6
# score                       0
# thumbsupcount               0
# reviewcreatedversion    26036
# at                          0
# appversion              26036
# dtype: int64

# %%
df['content'].value_counts().head(5).plot(kind='bar')
plt.savefig(r"C:\Users\punal\OneDrive\Desktop\Canaan Ed & Tech Internship\Week 1\Charts\bar_chart.png")
plt.show()

# %%
df['thumbsupcount'].head(1000).plot(kind='line')
plt.savefig(r"C:\Users\punal\OneDrive\Desktop\Canaan Ed & Tech Internship\Week 1\Charts\line_chart.png")
plt.show()

# %%
df['reviewcreatedversion'].value_counts().head(5).plot(kind='pie', autopct='%1.1f%%')
plt.savefig(r"C:\Users\punal\OneDrive\Desktop\Canaan Ed & Tech Internship\Week 1\Charts\pie_chart.png")
plt.show()
